# %% [markdown]
# <a href="https://colab.research.google.com/github/henry-heppe/SeminarML/blob/main/Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install Dependencies

# %%
# !pip install optuna
# !pip install git+https://github.com/JakeColtman/bartpy.git --no-deps

# %% [markdown]
# # Import Dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.metrics import mean_squared_error, mean_absolute_error
from bartpy.sklearnmodel import SklearnModel
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import KFold
import lightgbm as lgb
import optuna

# %% [markdown]
# # Parameters

# %%
# Set the Seed
randomSeed = 100

# Number of Splits
numberSplits = 5

# %% [markdown]
# # Initialize DataFrame

# %%
# Load the data and remove object type data
boatsDF1 = pd.read_csv('1_df_nan.csv', sep= ',', index_col=0)
boatsDF2 = pd.read_csv('2_df_man.csv', sep= ',', index_col=0)
boatsDF3 = pd.read_csv('3_df_man_PCA.csv', sep= ',', index_col=0)
boatsDF4 = pd.read_csv('4_df_man_noNanCat.csv', sep= ',', index_col=0)
boatsDF5 = pd.read_csv('5_df_freq.csv', sep= ',', index_col=0)
boatsDF6 = pd.read_csv('6_df_freq_PCA.csv', sep= ',', index_col=0)
boatsDF7 = pd.read_csv('7_df_freq_noNanCat.csv', sep= ',', index_col=0)

# Dictionary of boat frames with NaN values
boatFramesWithNaN = {'df1': boatsDF1}

# Dictionary of boat frames without NaN values
boatFramesWithoutNaN = {'df2': boatsDF2, 'df3': boatsDF3, 'df4': boatsDF4, 'df5': boatsDF5, 'df6': boatsDF6, 'df7': boatsDF7}

# Dictionary of all boat frames
allBoatFrames = {'df1': boatsDF1, 'df2': boatsDF2, 'df3': boatsDF3, 'df4': boatsDF4, 'df5': boatsDF5, 'df6': boatsDF6, 'df7': boatsDF7}

# %% [markdown]
# # Parameter Optimization

# %%
X = boatsDF1.drop(['Price'], axis=1)
y = boatsDF1['Price']

def objective(trial):
    # Define the hyperparameter search space
    param = {
        'objective': 'reg:squarederror',
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'alpha': trial.suggest_float('alpha', 5, 15),
        'n_estimators': trial.suggest_int('n_estimators', 50, 200),
    }

    rmseTotal = 0
    kFold = KFold(n_splits= numberSplits, shuffle=True, random_state= randomSeed)

    for train_index, test_index in kFold.split(X):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]

        threshold = np.quantile(y_train, 0.7)
        weights = np.where(y_train > threshold, 2.0, 1.0)

        # Define the model
        model = xgb.XGBRegressor(**param)

        # Train the model on the training set
        model.fit(X_train, y_train, sample_weight=weights)

        # Make predictions on the testing set
        y_pred = model.predict(X_test)

        # Calculate and save the RMSE for this fold
        mse = mean_squared_error(y_test, y_pred)
        rmse = np.sqrt(mse)
        rmseTotal = rmseTotal + rmse

    rmseAverage = rmseTotal / numberSplits

    return -rmseAverage

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

print(f"Best trial: RMSE = {-study.best_value}")
print(f"Optimized parameters: {study.best_params}")
# Out:
# [I 2024-04-06 16:26:34,686] A new study created in memory with name: no-name-5037fb00-f3a8-4dff-833e-25a0801724b6
# [I 2024-04-06 16:27:25,361] Trial 0 finished with value: -40341.699999906705 and parameters: {'colsample_bytree': 0.6265528923242114, 'learning_rate': 0.09292733270402989, 'max_depth': 12, 'alpha': 11.75963384152168, 'n_estimators': 160}. Best is trial 0 with value: -40341.699999906705.
# [I 2024-04-06 16:27:30,176] Trial 1 finished with value: -43249.01932098011 and parameters: {'colsample_bytree': 0.7196716333665005, 'learning_rate': 0.036168960034027066, 'max_depth': 5, 'alpha': 10.884928736284126, 'n_estimators': 94}. Best is trial 0 with value: -40341.699999906705.
# [I 2024-04-06 16:27:53,434] Trial 2 finished with value: -39852.1618414811 and parameters: {'colsample_bytree': 0.6870537000589969, 'learning_rate': 0.09639629443233443, 'max_depth': 10, 'alpha': 5.380706963971736, 'n_estimators': 120}. Best is trial 2 with value: -39852.1618414811.
# [I 2024-04-06 16:28:00,319] Trial 3 finished with value: -39806.742712047766 and parameters: {'colsample_bytree': 0.6682065619984154, 'learning_rate': 0.061359499602046376, 'max_depth': 8, 'alpha': 11.320871552139113, 'n_estimators': 82}. Best is trial 3 with value: -39806.742712047766.
# [I 2024-04-06 16:28:11,150] Trial 4 finished with value: -39281.127373943345 and parameters: {'colsample_bytree': 0.5113378117717096, 'learning_rate': 0.08516686766278579, 'max_depth': 8, 'alpha': 12.63720895440509, 'n_estimators': 156}. Best is trial 4 with value: -39281.127373943345.
# [I 2024-04-06 16:28:31,697] Trial 5 finished with value: -39423.96502157387 and parameters: {'colsample_bytree': 0.6068358262042138, 'learning_rate': 0.0919040367958131, 'max_depth': 10, 'alpha': 7.894206177299412, 'n_estimators': 121}. Best is trial 4 with value: -39281.127373943345.
# [I 2024-04-06 16:28:49,551] Trial 6 finished with value: -41843.01233886548 and parameters: {'colsample_bytree': 0.7019604134114144, 'learning_rate': 0.046167890760140974, 'max_depth': 11, 'alpha': 13.520790650287333, 'n_estimators': 56}. Best is trial 4 with value: -39281.127373943345.
# [I 2024-04-06 16:28:58,383] Trial 7 finished with value: -39617.1581279367 and parameters: {'colsample_bytree': 0.6672446029264221, 'learning_rate': 0.045172682487516, 'max_depth': 7, 'alpha': 8.987490614566907, 'n_estimators': 132}. Best is trial 4 with value: -39281.127373943345.
# [I 2024-04-06 16:29:00,179] Trial 8 finished with value: -46557.91127039247 and parameters: {'colsample_bytree': 0.5120404488576786, 'learning_rate': 0.047795989641192985, 'max_depth': 3, 'alpha': 14.732172027869844, 'n_estimators': 105}. Best is trial 4 with value: -39281.127373943345.
# [I 2024-04-06 16:30:20,157] Trial 9 finished with value: -41261.928226140575 and parameters: {'colsample_bytree': 0.9986205581315226, 'learning_rate': 0.06865613683362906, 'max_depth': 12, 'alpha': 6.5807994816418445, 'n_estimators': 174}. Best is trial 4 with value: -39281.127373943345.
# [I 2024-04-06 16:30:34,401] Trial 10 finished with value: -42227.386494969236 and parameters: {'colsample_bytree': 0.8271886768039407, 'learning_rate': 0.013618733699394488, 'max_depth': 7, 'alpha': 13.037448315009332, 'n_estimators': 191}. Best is trial 4 with value: -39281.127373943345.
# [I 2024-04-06 16:30:49,280] Trial 11 finished with value: -39402.19150664074 and parameters: {'colsample_bytree': 0.5012142161318338, 'learning_rate': 0.0794593823214332, 'max_depth': 9, 'alpha': 8.613594100961219, 'n_estimators': 149}. Best is trial 4 with value: -39281.127373943345.
# [I 2024-04-06 16:31:04,000] Trial 12 finished with value: -39462.1784566177 and parameters: {'colsample_bytree': 0.5066444095373641, 'learning_rate': 0.07641363119422617, 'max_depth': 9, 'alpha': 9.361363025741596, 'n_estimators': 145}. Best is trial 4 with value: -39281.127373943345.
# [I 2024-04-06 16:31:10,891] Trial 13 finished with value: -39818.39304729291 and parameters: {'colsample_bytree': 0.5628450342863746, 'learning_rate': 0.0797209556920335, 'max_depth': 6, 'alpha': 7.5002543405877535, 'n_estimators': 159}. Best is trial 4 with value: -39281.127373943345.
# [I 2024-04-06 16:31:34,364] Trial 14 finished with value: -39292.09478733524 and parameters: {'colsample_bytree': 0.8391191878427144, 'learning_rate': 0.0785468241101252, 'max_depth': 9, 'alpha': 10.18618191022569, 'n_estimators': 188}. Best is trial 4 with value: -39281.127373943345.
# [I 2024-04-06 16:31:38,205] Trial 15 finished with value: -41757.85205621731 and parameters: {'colsample_bytree': 0.8149104807500753, 'learning_rate': 0.06626960971948735, 'max_depth': 4, 'alpha': 12.546766698302875, 'n_estimators': 199}. Best is trial 4 with value: -39281.127373943345.
# [I 2024-04-06 16:31:55,205] Trial 16 finished with value: -39093.03208887684 and parameters: {'colsample_bytree': 0.865655816206325, 'learning_rate': 0.086578910260702, 'max_depth': 8, 'alpha': 10.806174828036951, 'n_estimators': 181}. Best is trial 16 with value: -39093.03208887684.
# [I 2024-04-06 16:32:03,534] Trial 17 finished with value: -39824.5876268812 and parameters: {'colsample_bytree': 0.9124282507369821, 'learning_rate': 0.08559097087365908, 'max_depth': 6, 'alpha': 14.253498870571473, 'n_estimators': 174}. Best is trial 16 with value: -39093.03208887684.
# [I 2024-04-06 16:32:17,496] Trial 18 finished with value: -39221.74727032673 and parameters: {'colsample_bytree': 0.7756124714935843, 'learning_rate': 0.09969455484829107, 'max_depth': 8, 'alpha': 12.028762488359868, 'n_estimators': 175}. Best is trial 16 with value: -39093.03208887684.
# [I 2024-04-06 16:32:25,280] Trial 19 finished with value: -39638.549336595504 and parameters: {'colsample_bytree': 0.7649323890016593, 'learning_rate': 0.09913065573417555, 'max_depth': 6, 'alpha': 10.623260255990603, 'n_estimators': 176}. Best is trial 16 with value: -39093.03208887684.
# [I 2024-04-06 16:33:04,963] Trial 20 finished with value: -40374.83206985767 and parameters: {'colsample_bytree': 0.8883782442986777, 'learning_rate': 0.025135322634373455, 'max_depth': 10, 'alpha': 11.902761264181596, 'n_estimators': 138}. Best is trial 16 with value: -39093.03208887684.
# [I 2024-04-06 16:33:18,166] Trial 21 finished with value: -39164.55051174635 and parameters: {'colsample_bytree': 0.7707012507113121, 'learning_rate': 0.08797454223665208, 'max_depth': 8, 'alpha': 12.57253283135086, 'n_estimators': 163}. Best is trial 16 with value: -39093.03208887684.
# [I 2024-04-06 16:33:32,266] Trial 22 finished with value: -38965.187135088505 and parameters: {'colsample_bytree': 0.7744957658076856, 'learning_rate': 0.08877386505523727, 'max_depth': 8, 'alpha': 13.917719830076255, 'n_estimators': 179}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:33:43,999] Trial 23 finished with value: -39558.98976494868 and parameters: {'colsample_bytree': 0.8913536336205057, 'learning_rate': 0.07057771820819873, 'max_depth': 7, 'alpha': 13.879429340047434, 'n_estimators': 190}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:34:06,944] Trial 24 finished with value: -39307.886554216755 and parameters: {'colsample_bytree': 0.9530783109936649, 'learning_rate': 0.08792943515046414, 'max_depth': 9, 'alpha': 14.81056076901195, 'n_estimators': 168}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:34:23,455] Trial 25 finished with value: -39102.76323373567 and parameters: {'colsample_bytree': 0.7992920311722385, 'learning_rate': 0.05655347439068897, 'max_depth': 8, 'alpha': 13.616787371699926, 'n_estimators': 199}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:34:30,367] Trial 26 finished with value: -40597.25026574052 and parameters: {'colsample_bytree': 0.8053905644351175, 'learning_rate': 0.061089128777169294, 'max_depth': 5, 'alpha': 13.641463675687309, 'n_estimators': 200}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:34:41,909] Trial 27 finished with value: -39414.762029522404 and parameters: {'colsample_bytree': 0.8599492018326341, 'learning_rate': 0.05605908285480056, 'max_depth': 7, 'alpha': 13.240425695955016, 'n_estimators': 189}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:35:41,113] Trial 28 finished with value: -39648.58445120723 and parameters: {'colsample_bytree': 0.7405459990477696, 'learning_rate': 0.03232112189091334, 'max_depth': 11, 'alpha': 14.225040371268049, 'n_estimators': 183}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:36:01,509] Trial 29 finished with value: -39336.79234737578 and parameters: {'colsample_bytree': 0.8679905221116294, 'learning_rate': 0.0930305448107873, 'max_depth': 9, 'alpha': 9.644747414626679, 'n_estimators': 150}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:36:09,978] Trial 30 finished with value: -40599.038133933645 and parameters: {'colsample_bytree': 0.9394466302825208, 'learning_rate': 0.07431829672450387, 'max_depth': 5, 'alpha': 11.309716890643463, 'n_estimators': 181}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:36:23,570] Trial 31 finished with value: -39217.97007427125 and parameters: {'colsample_bytree': 0.7837106933464442, 'learning_rate': 0.08823631979056197, 'max_depth': 8, 'alpha': 12.458358481440968, 'n_estimators': 165}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:36:38,642] Trial 32 finished with value: -38986.40817507634 and parameters: {'colsample_bytree': 0.7388079427339012, 'learning_rate': 0.08371020350149701, 'max_depth': 8, 'alpha': 12.86079253521727, 'n_estimators': 200}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:36:49,887] Trial 33 finished with value: -39206.53882439885 and parameters: {'colsample_bytree': 0.7451081598342095, 'learning_rate': 0.08171272894146278, 'max_depth': 7, 'alpha': 11.366762123157054, 'n_estimators': 199}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:37:22,456] Trial 34 finished with value: -39506.5339606338 and parameters: {'colsample_bytree': 0.7267664913377513, 'learning_rate': 0.09384574632692118, 'max_depth': 10, 'alpha': 14.27597174823154, 'n_estimators': 193}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:37:37,384] Trial 35 finished with value: -39135.16155623216 and parameters: {'colsample_bytree': 0.7934582650196276, 'learning_rate': 0.07252028991359599, 'max_depth': 8, 'alpha': 13.17492033999616, 'n_estimators': 182}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:37:41,875] Trial 36 finished with value: -40137.41929629682 and parameters: {'colsample_bytree': 0.7000969931105506, 'learning_rate': 0.064203269268127, 'max_depth': 6, 'alpha': 10.539032813756831, 'n_estimators': 112}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:37:55,598] Trial 37 finished with value: -39047.11740154511 and parameters: {'colsample_bytree': 0.6498523643106595, 'learning_rate': 0.05190163602853154, 'max_depth': 8, 'alpha': 14.952316862579924, 'n_estimators': 168}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:38:07,259] Trial 38 finished with value: -41555.911149882384 and parameters: {'colsample_bytree': 0.6295005176464025, 'learning_rate': 0.0368287374693985, 'max_depth': 9, 'alpha': 14.825016670376275, 'n_estimators': 75}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:38:38,472] Trial 39 finished with value: -39511.45039385308 and parameters: {'colsample_bytree': 0.6376918233483112, 'learning_rate': 0.04167203472763649, 'max_depth': 10, 'alpha': 14.937578466042224, 'n_estimators': 154}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:39:19,023] Trial 40 finished with value: -39665.94982566766 and parameters: {'colsample_bytree': 0.6670148524518779, 'learning_rate': 0.050756421217779145, 'max_depth': 11, 'alpha': 14.053537013667462, 'n_estimators': 132}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:39:34,586] Trial 41 finished with value: -39074.070439960175 and parameters: {'colsample_bytree': 0.8464283344426236, 'learning_rate': 0.05607341595214907, 'max_depth': 8, 'alpha': 13.571572794633028, 'n_estimators': 169}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:39:47,208] Trial 42 finished with value: -39124.03865137333 and parameters: {'colsample_bytree': 0.5920589772520344, 'learning_rate': 0.08358664483684616, 'max_depth': 8, 'alpha': 5.289207015512925, 'n_estimators': 170}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:39:59,751] Trial 43 finished with value: -39535.14174585094 and parameters: {'colsample_bytree': 0.8453604645227524, 'learning_rate': 0.05064243048579969, 'max_depth': 7, 'alpha': 12.812593347009457, 'n_estimators': 160}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:40:10,406] Trial 44 finished with value: -39281.43066390916 and parameters: {'colsample_bytree': 0.6771399616741131, 'learning_rate': 0.05946388896280116, 'max_depth': 7, 'alpha': 12.158951823382601, 'n_estimators': 181}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:40:32,853] Trial 45 finished with value: -39260.75344131932 and parameters: {'colsample_bytree': 0.716097967872207, 'learning_rate': 0.04166609424108972, 'max_depth': 9, 'alpha': 13.316676200840888, 'n_estimators': 141}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:40:41,516] Trial 46 finished with value: -39444.386359003765 and parameters: {'colsample_bytree': 0.5413704378364608, 'learning_rate': 0.09178388438440897, 'max_depth': 8, 'alpha': 14.50434351799966, 'n_estimators': 93}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:41:02,399] Trial 47 finished with value: -39211.57000015847 and parameters: {'colsample_bytree': 0.8305793613798611, 'learning_rate': 0.06786054161956007, 'max_depth': 9, 'alpha': 11.617444251704487, 'n_estimators': 169}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:41:14,896] Trial 48 finished with value: -42924.19529423894 and parameters: {'colsample_bytree': 0.6489605230761789, 'learning_rate': 0.01396891685737539, 'max_depth': 7, 'alpha': 7.86736468780823, 'n_estimators': 185}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:41:33,537] Trial 49 finished with value: -39065.58990504488 and parameters: {'colsample_bytree': 0.8727578795718236, 'learning_rate': 0.07641143374298638, 'max_depth': 8, 'alpha': 6.504036610142508, 'n_estimators': 193}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:41:36,440] Trial 50 finished with value: -41003.82959800503 and parameters: {'colsample_bytree': 0.9012280697868233, 'learning_rate': 0.07572339027413934, 'max_depth': 6, 'alpha': 6.356282326444482, 'n_estimators': 54}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:41:55,442] Trial 51 finished with value: -39079.80919346195 and parameters: {'colsample_bytree': 0.9309121632555067, 'learning_rate': 0.08335357473611028, 'max_depth': 8, 'alpha': 6.383108205389683, 'n_estimators': 194}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:42:13,551] Trial 52 finished with value: -39184.03620527636 and parameters: {'colsample_bytree': 0.9945265132562773, 'learning_rate': 0.08188677784672714, 'max_depth': 8, 'alpha': 6.289710376284701, 'n_estimators': 194}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:42:34,352] Trial 53 finished with value: -39135.03629660228 and parameters: {'colsample_bytree': 0.9503883893280239, 'learning_rate': 0.09603143472141087, 'max_depth': 8, 'alpha': 6.99706927829803, 'n_estimators': 193}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:42:59,785] Trial 54 finished with value: -39280.78725633336 and parameters: {'colsample_bytree': 0.9180646509811357, 'learning_rate': 0.07780921605641347, 'max_depth': 9, 'alpha': 5.947483237412824, 'n_estimators': 187}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:43:07,473] Trial 55 finished with value: -39339.97374501587 and parameters: {'colsample_bytree': 0.5962208546631894, 'learning_rate': 0.0902021194858724, 'max_depth': 7, 'alpha': 8.73254122717457, 'n_estimators': 177}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:43:32,170] Trial 56 finished with value: -39457.75350952254 and parameters: {'colsample_bytree': 0.9241283772106528, 'learning_rate': 0.06472656294492468, 'max_depth': 9, 'alpha': 5.686312131054997, 'n_estimators': 172}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:43:54,965] Trial 57 finished with value: -39315.81294002304 and parameters: {'colsample_bytree': 0.9775032562969558, 'learning_rate': 0.05229340187274902, 'max_depth': 8, 'alpha': 7.421492464545721, 'n_estimators': 195}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:44:30,939] Trial 58 finished with value: -39700.22015060227 and parameters: {'colsample_bytree': 0.8782337364124195, 'learning_rate': 0.06982576782599434, 'max_depth': 10, 'alpha': 7.143054221122249, 'n_estimators': 177}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:44:41,004] Trial 59 finished with value: -39300.42874003599 and parameters: {'colsample_bytree': 0.8158530542287701, 'learning_rate': 0.0805312835952194, 'max_depth': 7, 'alpha': 5.008773356985715, 'n_estimators': 157}. Best is trial 22 with value: -38965.187135088505.
# [I 2024-04-06 16:44:55,122] Trial 60 finished with value: -38930.29697119105 and parameters: {'colsample_bytree': 0.8502852690454983, 'learning_rate': 0.09629425921472178, 'max_depth': 8, 'alpha': 8.312775401869258, 'n_estimators': 164}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:45:09,668] Trial 61 finished with value: -39290.57247916332 and parameters: {'colsample_bytree': 0.8509231585161563, 'learning_rate': 0.08383984772236311, 'max_depth': 8, 'alpha': 8.212721634931755, 'n_estimators': 164}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:45:33,742] Trial 62 finished with value: -39327.75451177421 and parameters: {'colsample_bytree': 0.7616667603977303, 'learning_rate': 0.09486593411746716, 'max_depth': 9, 'alpha': 13.793223227959064, 'n_estimators': 188}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:45:48,970] Trial 63 finished with value: -39329.23588904517 and parameters: {'colsample_bytree': 0.8854457120206822, 'learning_rate': 0.09820460900557801, 'max_depth': 8, 'alpha': 6.746657715077837, 'n_estimators': 177}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:45:58,528] Trial 64 finished with value: -39405.89213970779 and parameters: {'colsample_bytree': 0.8233890378316384, 'learning_rate': 0.0844429130164995, 'max_depth': 7, 'alpha': 14.489770557463581, 'n_estimators': 152}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:46:14,555] Trial 65 finished with value: -39261.101677616105 and parameters: {'colsample_bytree': 0.9077441858243717, 'learning_rate': 0.08808707680467691, 'max_depth': 8, 'alpha': 9.596286275278525, 'n_estimators': 184}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:46:35,135] Trial 66 finished with value: -39442.99768182575 and parameters: {'colsample_bytree': 0.8413274936982756, 'learning_rate': 0.09083820462888607, 'max_depth': 9, 'alpha': 8.2538970830174, 'n_estimators': 146}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:46:38,205] Trial 67 finished with value: -43704.05438227756 and parameters: {'colsample_bytree': 0.8722883449505896, 'learning_rate': 0.07334503275104694, 'max_depth': 3, 'alpha': 6.082829181295417, 'n_estimators': 196}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:46:46,729] Trial 68 finished with value: -40082.569933059276 and parameters: {'colsample_bytree': 0.9308221214625785, 'learning_rate': 0.058702361700989934, 'max_depth': 6, 'alpha': 12.995490398114889, 'n_estimators': 166}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:47:03,517] Trial 69 finished with value: -39177.151103623546 and parameters: {'colsample_bytree': 0.7887387052277282, 'learning_rate': 0.046293456853443674, 'max_depth': 8, 'alpha': 13.500725896348376, 'n_estimators': 190}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:47:14,937] Trial 70 finished with value: -39677.8987932346 and parameters: {'colsample_bytree': 0.9683922833532063, 'learning_rate': 0.09769586244655803, 'max_depth': 7, 'alpha': 14.509042498930913, 'n_estimators': 172}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:47:32,566] Trial 71 finished with value: -39292.8509740124 and parameters: {'colsample_bytree': 0.867339546354038, 'learning_rate': 0.08575503792921511, 'max_depth': 8, 'alpha': 10.996806209022468, 'n_estimators': 180}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:47:51,121] Trial 72 finished with value: -39117.05421602717 and parameters: {'colsample_bytree': 0.8572227284130376, 'learning_rate': 0.07795435725298838, 'max_depth': 8, 'alpha': 8.977695715554688, 'n_estimators': 200}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:48:13,407] Trial 73 finished with value: -39494.29483552253 and parameters: {'colsample_bytree': 0.8991258138976753, 'learning_rate': 0.08736902866912083, 'max_depth': 9, 'alpha': 9.952090449330981, 'n_estimators': 162}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:48:28,161] Trial 74 finished with value: -39076.6264324026 and parameters: {'colsample_bytree': 0.8111865339111016, 'learning_rate': 0.09385865437916054, 'max_depth': 8, 'alpha': 13.992833060665076, 'n_estimators': 179}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:48:40,853] Trial 75 finished with value: -39288.318543051675 and parameters: {'colsample_bytree': 0.8084564607755498, 'learning_rate': 0.09008189445426888, 'max_depth': 7, 'alpha': 14.0161285949926, 'n_estimators': 187}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:48:48,640] Trial 76 finished with value: -39494.753298398864 and parameters: {'colsample_bytree': 0.7589694421750914, 'learning_rate': 0.09998298674012678, 'max_depth': 8, 'alpha': 13.48015107748364, 'n_estimators': 67}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:49:11,336] Trial 77 finished with value: -39265.86329555923 and parameters: {'colsample_bytree': 0.7338988593186696, 'learning_rate': 0.09478872820901288, 'max_depth': 9, 'alpha': 13.780191838946438, 'n_estimators': 192}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:49:25,769] Trial 78 finished with value: -39021.87641217794 and parameters: {'colsample_bytree': 0.8323686477833043, 'learning_rate': 0.09282001061531292, 'max_depth': 8, 'alpha': 14.988656610136019, 'n_estimators': 174}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:49:38,993] Trial 79 finished with value: -39133.767351692724 and parameters: {'colsample_bytree': 0.7765761662055836, 'learning_rate': 0.09270646978568856, 'max_depth': 8, 'alpha': 14.623975979031936, 'n_estimators': 159}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:49:49,368] Trial 80 finished with value: -39245.46952803804 and parameters: {'colsample_bytree': 0.8345515698452828, 'learning_rate': 0.09689769424321176, 'max_depth': 7, 'alpha': 14.219975585596002, 'n_estimators': 169}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:50:05,127] Trial 81 finished with value: -39029.38913424713 and parameters: {'colsample_bytree': 0.821836027634971, 'learning_rate': 0.05420038381806321, 'max_depth': 8, 'alpha': 14.896509126075301, 'n_estimators': 179}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:50:21,099] Trial 82 finished with value: -39152.382643429264 and parameters: {'colsample_bytree': 0.8248533778354209, 'learning_rate': 0.051247771014190556, 'max_depth': 8, 'alpha': 14.993105051555979, 'n_estimators': 174}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:50:45,571] Trial 83 finished with value: -39262.12439822858 and parameters: {'colsample_bytree': 0.8137832919272838, 'learning_rate': 0.05474565443216593, 'max_depth': 9, 'alpha': 14.719840077442997, 'n_estimators': 179}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:51:04,418] Trial 84 finished with value: -39310.901361209195 and parameters: {'colsample_bytree': 0.8035703992877399, 'learning_rate': 0.04319029362838327, 'max_depth': 8, 'alpha': 14.205030618648486, 'n_estimators': 185}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:51:15,021] Trial 85 finished with value: -39337.443390909946 and parameters: {'colsample_bytree': 0.7507954151379771, 'learning_rate': 0.05526712647419434, 'max_depth': 7, 'alpha': 14.418594212628278, 'n_estimators': 166}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:51:38,416] Trial 86 finished with value: -39104.57901199874 and parameters: {'colsample_bytree': 0.7046745126713676, 'learning_rate': 0.06273349015164546, 'max_depth': 9, 'alpha': 13.970156143301335, 'n_estimators': 174}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:51:58,234] Trial 87 finished with value: -39244.31469119914 and parameters: {'colsample_bytree': 0.8461761724736859, 'learning_rate': 0.04744485529358502, 'max_depth': 8, 'alpha': 12.260487134713614, 'n_estimators': 184}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:52:07,753] Trial 88 finished with value: -40134.46904754116 and parameters: {'colsample_bytree': 0.790946896243285, 'learning_rate': 0.03674977761578826, 'max_depth': 7, 'alpha': 12.812370650146494, 'n_estimators': 117}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:53:06,448] Trial 89 finished with value: -40304.70391369281 and parameters: {'colsample_bytree': 0.5601543506329858, 'learning_rate': 0.05354144044291009, 'max_depth': 12, 'alpha': 14.998821822377131, 'n_estimators': 155}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:53:31,482] Trial 90 finished with value: -39347.63244551183 and parameters: {'colsample_bytree': 0.857965955848541, 'learning_rate': 0.049549065453693586, 'max_depth': 9, 'alpha': 14.63858982442333, 'n_estimators': 171}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:53:47,119] Trial 91 finished with value: -39140.03517889076 and parameters: {'colsample_bytree': 0.7781310124924519, 'learning_rate': 0.08973436180008693, 'max_depth': 8, 'alpha': 6.548009757350965, 'n_estimators': 196}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:54:03,588] Trial 92 finished with value: -39123.639964375354 and parameters: {'colsample_bytree': 0.8802665284070974, 'learning_rate': 0.08249600273844301, 'max_depth': 8, 'alpha': 13.676244492064852, 'n_estimators': 190}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:54:20,875] Trial 93 finished with value: -38934.192414042234 and parameters: {'colsample_bytree': 0.8195300639801447, 'learning_rate': 0.09236374801259344, 'max_depth': 8, 'alpha': 14.12506604842524, 'n_estimators': 180}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:54:35,360] Trial 94 finished with value: -39187.767633652395 and parameters: {'colsample_bytree': 0.798974462761566, 'learning_rate': 0.09438482124158286, 'max_depth': 8, 'alpha': 13.379145541265085, 'n_estimators': 179}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:54:47,447] Trial 95 finished with value: -39180.09548413851 and parameters: {'colsample_bytree': 0.8209920023185683, 'learning_rate': 0.09220101937203704, 'max_depth': 7, 'alpha': 14.363578457967742, 'n_estimators': 168}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:55:05,258] Trial 96 finished with value: -39513.697466774785 and parameters: {'colsample_bytree': 0.8337854556195489, 'learning_rate': 0.028099072011411357, 'max_depth': 8, 'alpha': 14.034541057968251, 'n_estimators': 161}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:55:29,050] Trial 97 finished with value: -39251.00156019377 and parameters: {'colsample_bytree': 0.8500372532008241, 'learning_rate': 0.05838328941801791, 'max_depth': 9, 'alpha': 14.775571091316413, 'n_estimators': 176}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:55:42,285] Trial 98 finished with value: -39140.54392899662 and parameters: {'colsample_bytree': 0.6162944556464093, 'learning_rate': 0.09603541021769252, 'max_depth': 8, 'alpha': 13.15532655369812, 'n_estimators': 181}. Best is trial 60 with value: -38930.29697119105.
# [I 2024-04-06 16:55:53,069] Trial 99 finished with value: -39571.892193465916 and parameters: {'colsample_bytree': 0.8379578615481842, 'learning_rate': 0.08676993657235513, 'max_depth': 7, 'alpha': 14.202029809375592, 'n_estimators': 131}. Best is trial 60 with value: -38930.29697119105.
# Best trial: RMSE = 38930.29697119105
# Optimized parameters: {'colsample_bytree': 0.8502852690454983, 'learning_rate': 0.09629425921472178, 'max_depth': 8, 'alpha': 8.312775401869258, 'n_estimators': 164}

# %% [markdown]
# # XGBoost

# %%
rmseValuesXGBoost = {}
maeValuesXGBoost = {}

for name, boatFrame in allBoatFrames.items():
  X = boatFrame.drop(['Price'], axis=1)
  y = boatFrame['Price']
  rmseTotal = 0
  maeTotal = 0

  kFold = KFold(n_splits= numberSplits, shuffle=True, random_state= randomSeed)

  for train_index, test_index in kFold.split(X):
      X_train, X_test = X.iloc[train_index], X.iloc[test_index]
      y_train, y_test = y.iloc[train_index], y.iloc[test_index]

      threshold = np.quantile(y_train, 0.7)
      weights = np.where(y_train > threshold, 2.0, 1.0)

      # Define the model
      model = xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree = 0.85, learning_rate = 0.096,
                              max_depth = 8, alpha = 8.31, n_estimators = 164)

      # Train the model on the training set
      model.fit(X_train, y_train, sample_weight=weights)

      # Make predictions on the testing set
      y_pred = model.predict(X_test)

      # Calculate and save the RMSE for this fold
      mse = mean_squared_error(y_test, y_pred)
      rmse = np.sqrt(mse)
      rmseTotal = rmseTotal + rmse

      # Calculate and save the MAE for this fold
      mae = mean_absolute_error(y_test, y_pred)
      maeTotal = maeTotal + mae

  rmseAverage = rmseTotal / numberSplits
  maeAverage = maeTotal / numberSplits
  rmseValuesXGBoost[f'rmse_value_{name}'] = rmseAverage
  maeValuesXGBoost[f'mae_value_{name}'] = maeAverage

print(list(rmseValuesXGBoost.keys()))
print(list(rmseValuesXGBoost.values()))
print(list(maeValuesXGBoost.keys()))
print(list(maeValuesXGBoost.values()))
# Out:
# ['rmse_value_df1', 'rmse_value_df2', 'rmse_value_df3', 'rmse_value_df4', 'rmse_value_df5', 'rmse_value_df6', 'rmse_value_df7']
# [39236.96852929885, 39522.79583546046, 39933.475455101165, 39629.3795418613, 39461.35662393279, 39898.549465551114, 39372.278347449]
# ['mae_value_df1', 'mae_value_df2', 'mae_value_df3', 'mae_value_df4', 'mae_value_df5', 'mae_value_df6', 'mae_value_df7']
# [23378.732219079422, 23510.27271705715, 23804.6338619908, 23524.706034709514, 23610.786629162125, 24056.77105094958, 23612.748616502864]

# %% [markdown]
# # Light GBM

# %%
rmseValuesLGBM = {}
maeValuesLGBM = {}

for name, boatFrame in allBoatFrames.items():
  X = boatFrame.drop(['Price'], axis=1)
  y = boatFrame['Price']
  rmseTotal = 0
  maeTotal = 0

  kFold = KFold(n_splits= numberSplits, shuffle=True, random_state= randomSeed)

  for train_index, test_index in kFold.split(X):
      X_train, X_test = X.iloc[train_index], X.iloc[test_index]
      y_train, y_test = y.iloc[train_index], y.iloc[test_index]

      threshold = np.quantile(y_train, 0.7)
      weights = np.where(y_train > threshold, 2.0, 1.0)

      # Define the model
      model = lgb.LGBMRegressor(boosting_type='gbdt', num_leaves= 256, colsample_bytree = 0.85, max_depth= 8,
                             learning_rate= 0.096, n_estimators= 164, subsample_for_bin=200000,
                             reg_alpha = 8.31, random_state=randomSeed, verbose=-1)

      # Train the model on the training set
      model.fit(X_train, y_train, sample_weight=weights)

      # Make predictions on the testing set
      y_pred = model.predict(X_test)

      # Calculate and save the RMSE for this fold
      mse = mean_squared_error(y_test, y_pred)
      rmse = np.sqrt(mse)
      rmseTotal = rmseTotal + rmse

      # Calculate and save the MAE for this fold
      mae = mean_absolute_error(y_test, y_pred)
      maeTotal = maeTotal + mae

  rmseAverage = rmseTotal / numberSplits
  maeAverage = maeTotal / numberSplits
  rmseValuesLGBM[f'rmse_value_{name}'] = rmseAverage
  maeValuesLGBM[f'mae_value_{name}'] = maeAverage

print(list(rmseValuesLGBM.keys()))
print(list(rmseValuesLGBM.values()))
print(list(maeValuesLGBM.keys()))
print(list(maeValuesLGBM.values()))
# Out:
# ['rmse_value_df1', 'rmse_value_df2', 'rmse_value_df3', 'rmse_value_df4', 'rmse_value_df5', 'rmse_value_df6', 'rmse_value_df7']
# [39595.659065802596, 39758.71477428215, 39607.71982179379, 39764.59860947528, 39621.286013735255, 39657.53294411556, 39791.61742584813]
# ['mae_value_df1', 'mae_value_df2', 'mae_value_df3', 'mae_value_df4', 'mae_value_df5', 'mae_value_df6', 'mae_value_df7']
# [23900.16471834062, 23957.04246842853, 23877.166664528246, 23947.84202101162, 23975.5465739197, 24040.994099128893, 24062.547172851842]

# %% [markdown]
# # Random Forest

# %%
rmseValuesRF = {}
maeValuesRF = {}

for name, boatFrame in boatFramesWithoutNaN.items():
  X = boatFrame.drop(['Price'], axis=1)
  y = boatFrame['Price']
  rmseTotal = 0
  maeTotal = 0

  kFold = KFold(n_splits=numberSplits, shuffle=True, random_state= randomSeed)

  for train_index, test_index in kFold.split(X):
      X_train, X_test = X.iloc[train_index], X.iloc[test_index]
      y_train, y_test = y.iloc[train_index], y.iloc[test_index]

      threshold = np.quantile(y_train, 0.7)
      weights = np.where(y_train > threshold, 2.0, 1.0)

      # Define the model
      model =RandomForestRegressor(n_estimators=200, random_state=randomSeed, n_jobs=-1)

      # Train the model on the training set
      model.fit(X_train, y_train, sample_weight=weights)

      # Make predictions on the testing set
      y_pred = model.predict(X_test)

      # Calculate and save the RMSE for this fold
      mse = mean_squared_error(y_test, y_pred)
      rmse = np.sqrt(mse)
      rmseTotal = rmseTotal + rmse

      # Calculate and save the MAE for this fold
      mae = mean_absolute_error(y_test, y_pred)
      maeTotal = maeTotal + mae

  rmseAverage = rmseTotal / numberSplits
  maeAverage = maeTotal / numberSplits
  rmseValuesRF[f'rmse_value_{name}'] = rmseAverage
  maeValuesRF[f'mae_value_{name}'] = maeAverage

print(list(rmseValuesRF.keys()))
print(list(rmseValuesRF.values()))
print(list(maeValuesRF.keys()))
print(list(maeValuesRF.values()))

# %% [markdown]
# # Bayesian Additive Regression Trees

# %%
rmseValuesBART = {}
maeValuesBART = {}

for name, boatFrame in boatFramesWithoutNaN.items():
  X = boatFrame.drop(['Price'], axis=1)
  y = boatFrame['Price']
  rmseTotal = 0
  maeTotal = 0

  kFold = KFold(n_splits= numberSplits, shuffle=True, random_state= randomSeed)

  for train_index, test_index in kFold.split(X):
      X_train, X_test = X.iloc[train_index], X.iloc[test_index]
      y_train, y_test = y.iloc[train_index], y.iloc[test_index]

      # Define the model
      model = SklearnModel(n_jobs=1, n_chains= 2)

      # Train the model on the training set
      model.fit(X_train, y_train)

      # Make predictions on the testing set
      y_pred = model.predict(X_test)

      # Calculate and save the RMSE for this fold
      mse = mean_squared_error(y_test, y_pred)
      rmse = np.sqrt(mse)
      rmseTotal = rmseTotal + rmse

      # Calculate and save the MAE for this fold
      mae = mean_absolute_error(y_test, y_pred)
      maeTotal = maeTotal + mae

  rmseAverage = rmseTotal / numberSplits
  maeAverage = maeTotal / numberSplits
  rmseValuesBART[f'rmse_value_{name}'] = rmseAverage
  maeValuesBART[f'mae_value_{name}'] = maeAverage

print(list(rmseValuesBART.keys()))
print(list(rmseValuesBART.values()))
print(list(maeValuesBART.keys()))
print(list(maeValuesBART.values()))

# %% [markdown]
# # Plotting Time

# %%
# Make an Actual vs Predicted Plot
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, alpha=0.5)
plt.title('Predictions vs. Actual Values')
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
plt.show()
